# %%
import pandas as pd
import altair as alt
import numpy as np

df = pd.read_csv('https://github.com/byuidatascience/data4missing/raw/master/data-raw/mtcars_missing/mtcars_missing.csv')

# %%
df
# Out:
#                     car   mpg  cyl   disp     hp  drat     wt   qsec   vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46  0.0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02  NaN   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61  1.0   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08    NaN  19.44  1.0   0
# 4     Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02  0.0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76    NaN  20.22  1.0   0
# 8              Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90  1.0   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92    NaN  18.30  1.0   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90  NaN   0
# 11           Merc 450SE  16.4    8  275.8  180.0  3.07  4.070  17.40  0.0   0
# 12           Merc 450SL  17.3    8  275.8  180.0  3.07    NaN  17.60  0.0   0
# 13          Merc 450SLC  15.2    8  275.8  180.0  3.07    NaN  18.00  0.0   0
# 14   Cadillac Fleetwood  10.4    8  472.0    NaN  2.93  5.250  17.98  NaN   0
# 15  Lincoln Continental  10.4    8  460.0    NaN  3.00    NaN  17.82  0.0   0
# 16    Chrysler Imperial  14.7    8  440.0    NaN  3.23    NaN  17.42  0.0   0
# 17             Fiat 128  32.4    4   78.7   66.0  4.08  2.200  19.47  1.0   1
# 19       Toyota Corolla  33.9    4   71.1   65.0  4.22  1.835  19.90  1.0   1
# 20        Toyota Corona  21.5    4  120.1   97.0  3.70    NaN  20.01  1.0   0
# 21     Dodge Challenger  15.5    8  318.0  150.0  2.76  3.520  16.87  0.0   0
# 23           Camaro Z28  13.3    8  350.0    NaN  3.73    NaN  15.41  0.0   0
# 24     Pontiac Firebird  19.2    8  400.0  175.0  3.08  3.845  17.05  NaN   0
# 25            Fiat X1-9  27.3    4   79.0   66.0  4.08    NaN  18.90  1.0   1
# 26        Porsche 914-2  26.0    4  120.3   91.0  4.43  2.140  16.70  0.0   1
# 27         Lotus Europa  30.4    4   95.1  113.0  3.77    NaN  16.90  1.0   1
# 28       Ford Pantera L  15.8    8  351.0    NaN  4.22    NaN  14.50  0.0   1
# 29         Ferrari Dino  19.7    6  145.0  175.0  3.62  2.770  15.50  NaN   1
# 30        Maserati Bora  15.0    8  301.0    NaN  3.54    NaN  14.60  NaN   1
# 31           Volvo 142E  21.4    4  121.0  109.0  4.11  2.780  18.60  1.0   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2    999     1
# 3      3     1
# 4      3     2
# 5      3     1
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17   999     1
# 19   999     1
# 20     3     1
# 21     3     2
# 23     3     4
# 24     3     2
# 25   999     1
# 26   999     2
# 27   999     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31   999     2

# %%
df = df.dropna(subset=['car'])
df
# Out:
#                     car   mpg  cyl   disp     hp  drat     wt   qsec   vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46  0.0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02  NaN   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61  1.0   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08    NaN  19.44  1.0   0
# 4     Hornet Sportabout  18.7    8  360.0  175.0  3.15  3.440  17.02  0.0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76    NaN  20.22  1.0   0
# 8              Merc 230  22.8    4  140.8   95.0  3.92  3.150  22.90  1.0   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92    NaN  18.30  1.0   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92  3.440  18.90  NaN   0
# 11           Merc 450SE  16.4    8  275.8  180.0  3.07  4.070  17.40  0.0   0
# 12           Merc 450SL  17.3    8  275.8  180.0  3.07    NaN  17.60  0.0   0
# 13          Merc 450SLC  15.2    8  275.8  180.0  3.07    NaN  18.00  0.0   0
# 14   Cadillac Fleetwood  10.4    8  472.0    NaN  2.93  5.250  17.98  NaN   0
# 15  Lincoln Continental  10.4    8  460.0    NaN  3.00    NaN  17.82  0.0   0
# 16    Chrysler Imperial  14.7    8  440.0    NaN  3.23    NaN  17.42  0.0   0
# 17             Fiat 128  32.4    4   78.7   66.0  4.08  2.200  19.47  1.0   1
# 19       Toyota Corolla  33.9    4   71.1   65.0  4.22  1.835  19.90  1.0   1
# 20        Toyota Corona  21.5    4  120.1   97.0  3.70    NaN  20.01  1.0   0
# 21     Dodge Challenger  15.5    8  318.0  150.0  2.76  3.520  16.87  0.0   0
# 23           Camaro Z28  13.3    8  350.0    NaN  3.73    NaN  15.41  0.0   0
# 24     Pontiac Firebird  19.2    8  400.0  175.0  3.08  3.845  17.05  NaN   0
# 25            Fiat X1-9  27.3    4   79.0   66.0  4.08    NaN  18.90  1.0   1
# 26        Porsche 914-2  26.0    4  120.3   91.0  4.43  2.140  16.70  0.0   1
# 27         Lotus Europa  30.4    4   95.1  113.0  3.77    NaN  16.90  1.0   1
# 28       Ford Pantera L  15.8    8  351.0    NaN  4.22    NaN  14.50  0.0   1
# 29         Ferrari Dino  19.7    6  145.0  175.0  3.62  2.770  15.50  NaN   1
# 30        Maserati Bora  15.0    8  301.0    NaN  3.54    NaN  14.60  NaN   1
# 31           Volvo 142E  21.4    4  121.0  109.0  4.11  2.780  18.60  1.0   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2    999     1
# 3      3     1
# 4      3     2
# 5      3     1
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17   999     1
# 19   999     1
# 20     3     1
# 21     3     2
# 23     3     4
# 24     3     2
# 25   999     1
# 26   999     2
# 27   999     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31   999     2

# %%
mean = df['hp'].mean()
mean
# Out:
# 122.31818181818181

# %%
df['hp'].replace(np.nan, mean, inplace=True)
# Out:
# /tmp/ipykernel_23069/37139341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hp'].replace(np.nan, mean, inplace=True)

# %%
df
# Out:
#                     car   mpg  cyl   disp          hp  drat     wt   qsec  \
# 0             Mazda RX4  21.0    6  160.0  110.000000  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0    6  160.0  110.000000  3.90  2.875  17.02
# 2            Datsun 710  22.8    4  108.0   93.000000  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4    6  258.0  110.000000  3.08    NaN  19.44
# 4     Hornet Sportabout  18.7    8  360.0  175.000000  3.15  3.440  17.02
# 5               Valiant  18.1    6  225.0  105.000000  2.76    NaN  20.22
# 8              Merc 230  22.8    4  140.8   95.000000  3.92  3.150  22.90
# 9              Merc 280  19.2    6  167.6  123.000000  3.92    NaN  18.30
# 10            Merc 280C  17.8    6  167.6  123.000000  3.92  3.440  18.90
# 11           Merc 450SE  16.4    8  275.8  180.000000  3.07  4.070  17.40
# 12           Merc 450SL  17.3    8  275.8  180.000000  3.07    NaN  17.60
# 13          Merc 450SLC  15.2    8  275.8  180.000000  3.07    NaN  18.00
# 14   Cadillac Fleetwood  10.4    8  472.0  122.318182  2.93  5.250  17.98
# 15  Lincoln Continental  10.4    8  460.0  122.318182  3.00    NaN  17.82
# 16    Chrysler Imperial  14.7    8  440.0  122.318182  3.23    NaN  17.42
# 17             Fiat 128  32.4    4   78.7   66.000000  4.08  2.200  19.47
# 19       Toyota Corolla  33.9    4   71.1   65.000000  4.22  1.835  19.90
# 20        Toyota Corona  21.5    4  120.1   97.000000  3.70    NaN  20.01
# 21     Dodge Challenger  15.5    8  318.0  150.000000  2.76  3.520  16.87
# 23           Camaro Z28  13.3    8  350.0  122.318182  3.73    NaN  15.41
# 24     Pontiac Firebird  19.2    8  400.0  175.000000  3.08  3.845  17.05
# 25            Fiat X1-9  27.3    4   79.0   66.000000  4.08    NaN  18.90
# 26        Porsche 914-2  26.0    4  120.3   91.000000  4.43  2.140  16.70
# 27         Lotus Europa  30.4    4   95.1  113.000000  3.77    NaN  16.90
# 28       Ford Pantera L  15.8    8  351.0  122.318182  4.22    NaN  14.50
# 29         Ferrari Dino  19.7    6  145.0  175.000000  3.62  2.770  15.50
# 30        Maserati Bora  15.0    8  301.0  122.318182  3.54    NaN  14.60
# 31           Volvo 142E  21.4    4  121.0  109.000000  4.11  2.780  18.60
#
#      vs  am  gear  carb
# 0   0.0   1     4     4
# 1   NaN   1     4     4
# 2   1.0   1   999     1
# 3   1.0   0     3     1
# 4   0.0   0     3     2
# 5   1.0   0     3     1
# 8   1.0   0     4     2
# 9   1.0   0     4     4
# 10  NaN   0     4     4
# 11  0.0   0     3     3
# 12  0.0   0     3     3
# 13  0.0   0     3     3
# 14  NaN   0     3     4
# 15  0.0   0     3     4
# 16  0.0   0     3     4
# 17  1.0   1   999     1
# 19  1.0   1   999     1
# 20  1.0   0     3     1
# 21  0.0   0     3     2
# 23  0.0   0     3     4
# 24  NaN   0     3     2
# 25  1.0   1   999     1
# 26  0.0   1   999     2
# 27  1.0   1   999     2
# 28  0.0   1     5     4
# 29  NaN   1     5     6
# 30  NaN   1     5     8
# 31  1.0   1   999     2

# %%
chart = alt.Chart(df).mark_circle(color='red').encode(
    x=alt.X('hp', title='Horse Power'),
    y=alt.Y('mpg', title='Miles per Gallon')
).properties(
    title={'text': 'This is awesome.', 'anchor': 'start'}
)
chart
# Out:
# alt.Chart(...)

# %%
line80df = pd.DataFrame({'hp': [80]})

line80 = alt.Chart(line80df).mark_rule().encode(x = "hp")

line80label = alt.Chart(line80df).mark_text(
    text='Big',
    align='right',
    baseline='middle',
    dx=-10,
    dy=85
).encode(
    x='hp',
    y=alt.value(0)  # adjust label position
)



line80labelline = line80 + line80label
line80labelline
# Out:
# alt.LayerChart(...)

# %%
line160df = pd.DataFrame({'hp': [160]})

line160 = alt.Chart(line160df).mark_rule().encode(x = "hp")

line160label = alt.Chart(line160df).mark_text(
    text='Really Big',
    align='right',
    baseline='middle',
    dx=-10,
    dy=126
).encode(
    x='hp',
    y=alt.value(0)  # adjust label position
)

line160labelline  = line160 + line160label
line160labelline
# Out:
# alt.LayerChart(...)

# %%
chart_final = chart  + line80labelline + line160labelline

chart_final
# Out:
# alt.LayerChart(...)

# %%
table = pd.crosstab(df['cyl'], df['carb'])

table
# Out:
# carb  1  2  3  4  6  8
# cyl
# 4     5  4  0  0  0  0
# 6     2  0  0  4  1  0
# 8     0  3  3  5  0  1
